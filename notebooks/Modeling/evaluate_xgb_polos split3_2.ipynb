# %% [markdown]
# # Evaluate XGBoost Multi Polos Result
#
# Evaluation of each model of training polo

# %%
import sys
sys.path.append('../../src')
from utils import  generate_dataset_split
import pickle
from utils import load_model
from evaluator import XGBoostEvaluator
import pandas as pd

# %% [markdown]
# ## Comb 0

# %%
model_comb0 = load_model(f'../../data/models/split3_2/Recife/xgb_0.sav')

# %%
X_test, y_test  = generate_dataset_split(['Recife'])

eval_comb0 = XGBoostEvaluator(model_comb0)
eval_comb0.evaluate(X_test, y_test)
# Out:
# ['Recife']
# Accuracy: 0.7956429136282251
# F1 Score: 0.0
# ROC AUC Score: 0.7956429136282251
# Recall: 0.0
# Precision: 0.0
# c:\Users\Caio\Documents\GitHub\xai-nui-classification\venv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
eval_comb0.plot_roc_curve(y_test, "XGBOOST COMB 0")

# %%
eval_comb0.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Comb 1

# %%
model_comb1 = load_model(f'../../data/models/split3_2/Recife/xgb_1.sav')

# %%
X_test, y_test  = generate_dataset_split(['Recife'])

eval_comb1 = XGBoostEvaluator(model_comb1)
eval_comb1.evaluate(X_test, y_test)
# Out:
# ['Recife']
# Accuracy: 0.8163710295165042
# F1 Score: 0.41463943219374755
# ROC AUC Score: 0.8163710295165042
# Recall: 0.29476562800908984
# Precision: 0.6988402885581225

# %%
eval_comb1.plot_roc_curve(y_test, "XGBOOST COMB 1")

# %%
eval_comb1.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Comb 2

# %%
model_comb2 = load_model(f'../../data/models/split3_2/Recife/xgb_2.sav')

# %%
X_test, y_test  = generate_dataset_split(['Recife'])

eval_comb2 = XGBoostEvaluator(model_comb2)
eval_comb2.evaluate(X_test, y_test)
# Out:
# ['Recife']
# Accuracy: 0.7911198795056571
# F1 Score: 0.14642819788725028
# ROC AUC Score: 0.7911198795056571
# Recall: 0.08088433540037746
# Precision: 0.7720588235294118

# %%
eval_comb2.plot_roc_curve(y_test, "XGBOOST COMB 2")

# %%
eval_comb2.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Comb 3

# %%
model_comb3 = load_model(f'../../data/models/split3_2/Recife/xgb_3.sav')

# %%
X_test, y_test  = generate_dataset_split(['Recife'])

eval_comb3 = XGBoostEvaluator(model_comb3)
eval_comb3.evaluate(X_test, y_test)
# Out:
# ['Recife']
# Accuracy: 0.8076108451051984
# F1 Score: 0.0
# ROC AUC Score: 0.8076108451051984
# Recall: 0.0
# Precision: 0.0
# c:\Users\Caio\Documents\GitHub\xai-nui-classification\venv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
eval_comb3.plot_roc_curve(y_test, "XGBOOST COMB 3")

# %%
eval_comb3.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Comb 4

# %%
model_comb4 = load_model(f'../../data/models/split3_2/Recife/xgb_4.sav')

# %%
X_test, y_test  = generate_dataset_split(['Recife'])

eval_comb4 = XGBoostEvaluator(model_comb4)
eval_comb4.evaluate(X_test, y_test)
# Out:
# ['Recife']
# Accuracy: 0.7982533669218562
# F1 Score: 0.0029980397432448013
# ROC AUC Score: 0.7982533669218562
# Recall: 0.0015021376574355814
# Precision: 0.7222222222222222

# %%
eval_comb4.plot_roc_curve(y_test, "XGBOOST COMB 4")

# %%
eval_comb4.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Comb 5

# %%
model_comb5 = load_model(f'../../data/models/split3_2/Recife/xgb_5.sav')

# %%
X_test, y_test  = generate_dataset_split(['Recife'])

eval_comb5 = XGBoostEvaluator(model_comb5)
eval_comb5.evaluate(X_test, y_test)
# Out:
# ['Recife']
# Accuracy: 0.81209159037797
# F1 Score: 0.17707204767063922
# ROC AUC Score: 0.81209159037797
# Recall: 0.10072025574856526
# Precision: 0.7318779736915757

# %%
eval_comb5.plot_roc_curve(y_test, "XGBOOST COMB 5")

# %%
eval_comb5.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Comb 6

# %%
model_comb6 = load_model(f'../../data/models/split3_2/Recife/xgb_6.sav')

# %%
X_test, y_test  = generate_dataset_split(['Recife'])

eval_comb6 = XGBoostEvaluator(model_comb6)
eval_comb6.evaluate(X_test, y_test)
# Out:
# ['Recife']
# Accuracy: 0.7775322136178561
# F1 Score: 0.0
# ROC AUC Score: 0.7775322136178561
# Recall: 0.0
# Precision: 0.0
# c:\Users\Caio\Documents\GitHub\xai-nui-classification\venv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
eval_comb6.plot_roc_curve(y_test, "XGBOOST COMB 6")

# %%
eval_comb6.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Comb 7

# %%
model_comb7 = load_model(f'../../data/models/split3_2/Recife/xgb_7.sav')

# %%
X_test, y_test  = generate_dataset_split(['Recife'])

eval_comb7 = XGBoostEvaluator(model_comb7)
eval_comb7.evaluate(X_test, y_test)
# Out:
# ['Recife']
# Accuracy: 0.6811563650112387
# F1 Score: 0.0
# ROC AUC Score: 0.6811563650112387
# Recall: 0.0
# Precision: 0.0
# c:\Users\Caio\Documents\GitHub\xai-nui-classification\venv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
eval_comb7.plot_roc_curve(y_test, "XGBOOST COMB 7")

# %%
eval_comb7.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Comb 8

# %%
model_comb8 = load_model(f'../../data/models/split3_2/Recife/xgb_8.sav')

# %%
X_test, y_test  = generate_dataset_split(['Recife'])

eval_comb8 = XGBoostEvaluator(model_comb8)
eval_comb8.evaluate(X_test, y_test)
# Out:
# ['Recife']
# Accuracy: 0.6905595318082935
# F1 Score: 0.12469908521906596
# ROC AUC Score: 0.6905595318082935
# Recall: 0.06983014289565921
# Precision: 0.5820224719101124

# %%
eval_comb8.plot_roc_curve(y_test, "XGBOOST COMB 8")

# %%
eval_comb8.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Comb 9

# %%
model_comb9 = load_model(f'../../data/models/split3_2/Recife/xgb_9.sav')

# %%
X_test, y_test  = generate_dataset_split(['Recife'])

eval_comb9 = XGBoostEvaluator(model_comb9)
eval_comb9.evaluate(X_test, y_test)
# Out:
# ['Recife']
# Accuracy: 0.7789219207717686
# F1 Score: 0.0
# ROC AUC Score: 0.7789219207717686
# Recall: 0.0
# Precision: 0.0
# c:\Users\Caio\Documents\GitHub\xai-nui-classification\venv\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
eval_comb9.plot_roc_curve(y_test, "XGBOOST COMB 9")

# %%
eval_comb9.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Recife

# %%
polo6 = "Recife"
model_polo6 = load_model(f'../../data/models/polos/xgb_{polo6}.sav')

# %%
X_test_polo6 = pd.read_pickle(f"../../data/model_input/X_test_{polo6}.pkl").drop(['Polo'], axis=1)
y_test_polo6= pd.read_pickle(f"../../data/model_input/y_test_{polo6}.pkl")

eval_polo6 = XGBoostEvaluator(model_polo6)
eval_polo6.evaluate(X_test_polo6, y_test_polo6)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 X_test_polo6 = pd.read_pickle(f"../../data/model_input/X_test_{polo6}.pkl").drop(['Polo'], axis=1)
#       2 y_test_polo6= pd.read_pickle(f"../../data/model_input/y_test_{polo6}.pkl")
#       4 eval_polo6 = XGBoostEvaluator(model_polo6)
#
# File c:\Users\Caio\Documents\GitHub\xai-nui-classification\venv\lib\site-packages\pandas\io\pickle.py:190, in read_pickle(filepath_or_buffer, compression, storage_options)
#     124 """
#     125 Load pickled pandas object (or any object) from file.
#     126
#    (...)
#     187 4    4    9
#     188 """
#     189 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 190 with get_handle(
#     191     filepath_or_buffer,
#     192     "rb",
#     193     compression=compression,
#     194     is_text=False,
#     195     storage_options=storage_options,
#     196 ) as handles:
#     197
#     198     # 1) try standard library Pickle
#     199     # 2) try pickle_compat (older pandas version) to handle subclass changes
#     200     # 3) try pickle_compat with latin-1 encoding upon a UnicodeDecodeError
#     202     try:
#     203         # TypeError for Cython complaints about object.__new__ vs Tick.__new__
#     204         try:
#
# File c:\Users\Caio\Documents\GitHub\xai-nui-classification\venv\lib\site-packages\pandas\io\common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/model_input/X_test_Recife.pkl'

# %%
eval_polo6.plot_roc_curve(y_test_polo6, "XGBOOST RECIFE")

# %%
eval_polo6.plot_confusion_matrix(y_test_polo6)
