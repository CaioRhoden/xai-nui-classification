# %% [markdown]
# # Evaluate XGBoost Multi Polos Result
#
# Evaluation of each model of training polo

# %%
import sys
sys.path.append('../../../src')
from utils import  generate_dataset_split, load_combinations
import pickle
from mlxtend.classifier import EnsembleVoteClassifier
from evaluator import EnsambleEvaluator
import pandas as pd

# %%
addresses = []
cities = ['Porto Alegre', 'Marabá', 'Brasília', 'Juazeiro do Norte', 'Recife', 'Belo Horizonte']
for c in cities:
    addresses.append(f'../../../data/models/ensambles/{c}.sav')

# %% [markdown]
# ## Porto Alegre

# %%
with open(addresses[0], 'rb') as file:
    model = pickle.load(file)

# %%
X_test, y_test  = generate_dataset_split(['Porto Alegre'])

eval1 = EnsambleEvaluator(model)
eval1.evaluate(X_test, y_test)
# Out:
# Accuracy: 0.4869976003293272
# F1 Score: 0.20902384841049296
# ROC AUC Score: 0.8311362161406766
# Recall: 0.9091643660359572
# Precision: 0.11808640895574601

# %%
eval1.plot_roc_curve(y_test, "XGBOOST COMB 0")

# %%
eval1.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Marabá

# %%
with open(addresses[1], 'rb') as file:
    model = pickle.load(file)

# %%
X_test, y_test  = generate_dataset_split(['Marabá'])

eval1 = EnsambleEvaluator(model)
eval1.evaluate(X_test, y_test)
# Out:
# Accuracy: 0.30908375933936294
# F1 Score: 0.43693631827129975
# ROC AUC Score: 0.5912245162411565
# Recall: 0.9810855263157895
# Precision: 0.2810530655515637

# %%
eval1.plot_roc_curve(y_test, "XGBOOST COMB 0")

# %%
eval1.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Brasília

# %%
with open(addresses[2], 'rb') as file:
    model = pickle.load(file)

# %%
X_test, y_test  = generate_dataset_split(['Brasília'])

eval1 = EnsambleEvaluator(model)
eval1.evaluate(X_test, y_test)
# Out:
# Accuracy: 0.532142897365724
# F1 Score: 0.296485092762729
# ROC AUC Score: 0.7677497833019901
# Recall: 0.9051755338400289
# Precision: 0.1772753047916076

# %%
eval1.plot_roc_curve(y_test, "XGBOOST COMB 0")

# %%
eval1.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Juazeiro do Norte

# %%
with open(addresses[3], 'rb') as file:
    model = pickle.load(file)

# %%
X_test, y_test  = generate_dataset_split(['Juazeiro do Norte'])

eval1 = EnsambleEvaluator(model)
eval1.evaluate(X_test, y_test)
# Out:
# Accuracy: 0.2368927554084225
# F1 Score: 0.3487516425755585
# ROC AUC Score: 0.550773529729262
# Recall: 0.9567411679884643
# Precision: 0.21324120199260807

# %%
eval1.plot_roc_curve(y_test, "XGBOOST COMB 0")

# %%
eval1.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Recife

# %%
with open(addresses[4], 'rb') as file:
    model = pickle.load(file)

# %%
X_test, y_test  = generate_dataset_split(['Recife'])

eval1 = EnsambleEvaluator(model)
eval1.evaluate(X_test, y_test)
# Out:
# Accuracy: 0.33242656105813595
# F1 Score: 0.4264347596276934
# ROC AUC Score: 0.7815967924625149
# Recall: 0.9943766128721643
# Precision: 0.27141505466778804

# %%
eval1.plot_roc_curve(y_test, "XGBOOST COMB 0")

# %%
eval1.plot_confusion_matrix(y_test)

# %% [markdown]
# ## Belo Horizonte

# %%
with open(addresses[5], 'rb') as file:
    model = pickle.load(file)

# %%
X_test, y_test  = generate_dataset_split(['Belo Horizonte'])

eval1 = EnsambleEvaluator(model)
eval1.evaluate(X_test, y_test)
# Out:
# Accuracy: 0.5333210962226265
# F1 Score: 0.4641442914441918
# ROC AUC Score: 0.7709062273297312
# Recall: 0.9083545822708865
# Precision: 0.3117097023247834

# %%
eval1.plot_roc_curve(y_test, "XGBOOST COMB 0")

# %%
eval1.plot_confusion_matrix(y_test)
